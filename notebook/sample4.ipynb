# %%
# %matplotlib inline
import pandas as pd
df = pd.read_csv('./ruby_1.csv')
df
# Out:
#   name  ruby  php  python  perl
# 0   一郎   100   40      70    80
# 1   二郎    60   90      80    10
# 2   三郎    90   60      60    60
# 3   四郎    80   70      70    80

# %%
sort_by_ruby = df.sort_values(
    by='ruby', ascending=False
)
sort_by_ruby[['name', 'ruby']]
# Out:
#   name  ruby
# 0   一郎   100
# 2   三郎    90
# 3   四郎    80
# 1   二郎    60

# %%
df['mean'] = df.mean(axis=1)
df
# Out:
#   name  ruby  php  python  perl  mean
# 0   一郎   100   40      70    80  72.5
# 1   二郎    60   90      80    10  60.0
# 2   三郎    90   60      60    60  67.5
# 3   四郎    80   70      70    80  75.0

# %%
df.sort_values(
    by=['mean', 'ruby'], ascending=False
)[['name', 'mean', 'ruby']]
# Out:
#   name  mean  ruby
# 3   四郎  75.0    80
# 0   一郎  72.5   100
# 2   三郎  67.5    90
# 1   二郎  60.0    60

# %%
csv_url = 'https://www.mizuhobank.co.jp/rate/market/csv/quote.csv'
df = pd.read_csv(
    csv_url,
    skiprows=2,
    index_col=0,
    parse_dates=True
)
df_pri = df [['USD', 'GBP', 'EUR']]
df_pri.head(3)
# Out:
#                USD     GBP     EUR
# 2002-04-01  133.15  189.79  116.12
# 2002-04-02  133.20  191.78  117.18
# 2002-04-03  133.20  191.26  116.96

# %%
df_pri.plot()

# %%
df_pri['2015':].plot()

# %%
df_pri.resample('M').median().tail(3)
# Out:
#                 USD     GBP     EUR
# 2016-12-31  116.530  144.57  122.37
# 2017-01-31  114.700  141.28  122.07
# 2017-02-28  113.075  141.51  120.29

# %%
df_pri.resample('M').median().diff().tail(3)
# Out:
#               USD    GBP   EUR
# 2016-12-31  8.205  9.485  6.06
# 2017-01-31 -1.830 -3.290 -0.30
# 2017-02-28 -1.625  0.230 -1.78

# %%
df_pri.resample('M').median().pct_change().tail(3)
# Out:
#                  USD       GBP       EUR
# 2016-12-31  0.075744  0.070215  0.052102
# 2017-01-31 -0.015704 -0.022757 -0.002452
# 2017-02-28 -0.014167  0.001628 -0.014582

# %%
import matplotlib.pyplot as plt
plt.plot(df[['USD', 'GBP', 'EUR']])
plt.plot(df[['USD', 'GBP', 'EUR']].rolling(window=250).mean())
plt.show()
